# %%
from Bio.KEGG.KGML import KGML_parser
import os
import io
import re
import time
import pickle
import requests
import networkx as nx
from bioservices import KEGG
from Bio.KEGG.KGML import KGML_parser
import networkx as nx
from Bio.KEGG.KGML import KGML_parser
# from Bio.KEGG.REST import KEGG
import os, re, io, time, pickle, requests
import networkx as nx
from Bio.KEGG.KGML import KGML_parser
# from Bio.KEGG.REST import KEGG


import numpy as np

if not hasattr(np, 'float_'):
    np.float_ = np.float64
# Out:
# /home/sjaferia/.local/lib/python3.9/site-packages/bs4/css.py:40: UserWarning: The soupsieve package is not installed. CSS selectors cannot be used.
#   warnings.warn(

# %%
save_dir = "KEGG_graphs"
os.makedirs(save_dir, exist_ok=True)

# list of KEGG pathways for Homo sapiens
kegg = KEGG()
pathway_list = kegg.list("pathway", "hsa").strip().split("\n")

# Extract IDs like "hsa00010"
ids = [re.search(r"(hsa\d{5})", line).group(1) for line in pathway_list if re.search(r"(hsa\d{5})", line)]

# Remove overview / global metabolic maps (01xxx)
filtered_ids = [pid for pid in ids if not re.match(r"hsa01[1-3]\d\d", pid)]

graphs = []
names = []

for pid in filtered_ids[:300]:  # adjust as desired, I just thought 100 would be fine
    try:
        url = f"https://rest.kegg.jp/get/{pid}/kgml"
        resp = requests.get(url, timeout=20)

        if resp.status_code != 200 or "<pathway" not in resp.text:
            print(f"No KGML for {pid}")
            continue

        record = KGML_parser.read(io.StringIO(resp.text))

        # --- build directed graph ---
        G = nx.DiGraph()
        for e in record.entries.values():
            G.add_node(e.id, name=e.name, type=e.type)
        for r in record.relations:
            G.add_edge(r.entry1.id, r.entry2.id, type=r.type)

        # --- remove isolated nodes (before relabeling) ---
        isolates = list(nx.isolates(G))
        if isolates:
            G.remove_nodes_from(isolates)
            print(f"Removed {len(isolates)} isolated nodes from {pid}")

        # skip graphs that become empty
        if G.number_of_nodes() == 0 or G.number_of_edges() == 0:
            print(f"Skipping {pid} (empty after cleaning)")
            continue

        # --- convert labels to 0..N-1 integers ---
        G = nx.convert_node_labels_to_integers(G, ordering="sorted")

        # --- optional: enforce undirected if required by downstream model ---
        # G = G.to_undirected()

        # --- save ---
        nx.write_graphml(G, os.path.join(save_dir, f"{pid}.graphml"))
        graphs.append(G)
        names.append(pid)
        print(f"Saved {pid}: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

        time.sleep(0.5)

    except Exception as e:
        print(f"Failed {pid}: {e}")

# save all graphs to a single pickle
with open("train_data.dat", "wb") as f:
    pickle.dump(graphs, f)

print(f"\nSaved {len(graphs)} cleaned KEGG pathway graphs into 'train_data.dat'")
# Out:
# Removed 62 isolated nodes from hsa00010
# Saved hsa00010: 39 nodes, 84 edges
# Removed 35 isolated nodes from hsa00020
# Saved hsa00020: 37 nodes, 94 edges
# Removed 81 isolated nodes from hsa00030
# Saved hsa00030: 34 nodes, 92 edges
# Removed 131 isolated nodes from hsa00040
# Saved hsa00040: 21 nodes, 30 edges
# Removed 114 isolated nodes from hsa00051
# Saved hsa00051: 26 nodes, 50 edges
# Removed 88 isolated nodes from hsa00052
# Saved hsa00052: 26 nodes, 62 edges
# Removed 110 isolated nodes from hsa00053
# Saved hsa00053: 12 nodes, 17 edges
# Removed 113 isolated nodes from hsa00500
# Saved hsa00500: 28 nodes, 54 edges
# Removed 83 isolated nodes from hsa00620
# Saved hsa00620: 39 nodes, 109 edges
# Removed 126 isolated nodes from hsa00630
# Saved hsa00630: 39 nodes, 69 edges
# Removed 85 isolated nodes from hsa00640
# Saved hsa00640: 34 nodes, 84 edges
# Removed 98 isolated nodes from hsa00650
# Saved hsa00650: 22 nodes, 36 edges
# Removed 74 isolated nodes from hsa00562
# Saved hsa00562: 47 nodes, 98 edges
# Removed 217 isolated nodes from hsa00190
# Saved hsa00190: 3 nodes, 2 edges
# Removed 109 isolated nodes from hsa00910
# Saved hsa00910: 7 nodes, 6 edges
# Removed 158 isolated nodes from hsa00920
# Saved hsa00920: 11 nodes, 10 edges
# Removed 240 isolated nodes from hsa00061
# Saved hsa00061: 92 nodes, 225 edges
# Removed 43 isolated nodes from hsa00062
# Saved hsa00062: 41 nodes, 44 edges
# Removed 74 isolated nodes from hsa00071
# Saved hsa00071: 68 nodes, 141 edges
# Removed 81 isolated nodes from hsa00100
# Saved hsa00100: 43 nodes, 60 edges
# Removed 58 isolated nodes from hsa00120
# Saved hsa00120: 46 nodes, 62 edges
# Removed 109 isolated nodes from hsa00140
# Saved hsa00140: 120 nodes, 358 edges
# Removed 68 isolated nodes from hsa00561
# Saved hsa00561: 20 nodes, 49 edges
# Removed 102 isolated nodes from hsa00564
# Saved hsa00564: 57 nodes, 159 edges
# Removed 29 isolated nodes from hsa00565
# Saved hsa00565: 20 nodes, 35 edges
# Removed 47 isolated nodes from hsa00600
# Saved hsa00600: 54 nodes, 208 edges
# Removed 88 isolated nodes from hsa00590
# Saved hsa00590: 51 nodes, 225 edges
# Removed 43 isolated nodes from hsa00591
# Saved hsa00591: 12 nodes, 41 edges
# Removed 64 isolated nodes from hsa00592
# Saved hsa00592: 7 nodes, 4 edges
# Removed 283 isolated nodes from hsa01040
# Skipping hsa01040 (empty after cleaning)
# Removed 178 isolated nodes from hsa00230
# Saved hsa00230: 104 nodes, 342 edges
# Removed 132 isolated nodes from hsa00240
# Saved hsa00240: 68 nodes, 191 edges
# Removed 48 isolated nodes from hsa00250
# Saved hsa00250: 60 nodes, 296 edges
# Removed 97 isolated nodes from hsa00260
# Saved hsa00260: 52 nodes, 189 edges
# Removed 136 isolated nodes from hsa00270
# Saved hsa00270: 51 nodes, 109 edges
# Removed 54 isolated nodes from hsa00280
# Saved hsa00280: 56 nodes, 126 edges
# Removed 45 isolated nodes from hsa00290
# Saved hsa00290: 6 nodes, 4 edges
# Removed 95 isolated nodes from hsa00310
# Saved hsa00310: 29 nodes, 29 edges
# Removed 49 isolated nodes from hsa00220
# Saved hsa00220: 21 nodes, 44 edges
# Removed 136 isolated nodes from hsa00330
# Saved hsa00330: 50 nodes, 94 edges
# Removed 69 isolated nodes from hsa00340
# Saved hsa00340: 18 nodes, 24 edges
# Removed 131 isolated nodes from hsa00350
# Saved hsa00350: 49 nodes, 121 edges
# Removed 106 isolated nodes from hsa00360
# Saved hsa00360: 14 nodes, 32 edges
# Removed 119 isolated nodes from hsa00380
# Saved hsa00380: 45 nodes, 83 edges
# Removed 89 isolated nodes from hsa00400
# Saved hsa00400: 26 nodes, 80 edges
# Removed 47 isolated nodes from hsa00410
# Saved hsa00410: 29 nodes, 91 edges
# Removed 42 isolated nodes from hsa00430
# Saved hsa00430: 12 nodes, 24 edges
# Removed 101 isolated nodes from hsa00440
# Saved hsa00440: 4 nodes, 2 edges
# Removed 37 isolated nodes from hsa00450
# Saved hsa00450: 13 nodes, 14 edges
# Removed 137 isolated nodes from hsa00470
# Saved hsa00470: 8 nodes, 4 edges
# Removed 80 isolated nodes from hsa00480
# Saved hsa00480: 27 nodes, 82 edges
# Removed 160 isolated nodes from hsa00520
# Saved hsa00520: 57 nodes, 90 edges
# Removed 235 isolated nodes from hsa00541
# Saved hsa00541: 18 nodes, 21 edges
# Removed 85 isolated nodes from hsa00510
# Saved hsa00510: 43 nodes, 59 edges
# Removed 164 isolated nodes from hsa00513
# Saved hsa00513: 32 nodes, 28 edges
# Removed 43 isolated nodes from hsa00512
# Saved hsa00512: 14 nodes, 25 edges
# Removed 68 isolated nodes from hsa00515
# Saved hsa00515: 23 nodes, 24 edges
# Removed 46 isolated nodes from hsa00514
# Skipping hsa00514 (empty after cleaning)
# Removed 37 isolated nodes from hsa00532
# Saved hsa00532: 7 nodes, 6 edges
# Removed 44 isolated nodes from hsa00534
# Saved hsa00534: 7 nodes, 6 edges
# Removed 27 isolated nodes from hsa00533
# Skipping hsa00533 (empty after cleaning)
# Removed 58 isolated nodes from hsa00531
# Saved hsa00531: 22 nodes, 20 edges
# Removed 97 isolated nodes from hsa00563
# Saved hsa00563: 29 nodes, 34 edges
# Removed 94 isolated nodes from hsa00601
# Saved hsa00601: 79 nodes, 231 edges
# Removed 43 isolated nodes from hsa00603
# Saved hsa00603: 19 nodes, 29 edges
# Removed 40 isolated nodes from hsa00604
# Saved hsa00604: 29 nodes, 48 edges
# Removed 27 isolated nodes from hsa00511
# Skipping hsa00511 (empty after cleaning)
# Removed 65 isolated nodes from hsa00730
# Saved hsa00730: 8 nodes, 10 edges
# Removed 58 isolated nodes from hsa00740
# Saved hsa00740: 5 nodes, 6 edges
# Removed 52 isolated nodes from hsa00750
# Saved hsa00750: 12 nodes, 24 edges
# Removed 102 isolated nodes from hsa00760
# Saved hsa00760: 32 nodes, 95 edges
# Removed 48 isolated nodes from hsa00770
# Saved hsa00770: 20 nodes, 28 edges
# Removed 55 isolated nodes from hsa00780
# Saved hsa00780: 12 nodes, 23 edges
# Removed 76 isolated nodes from hsa00785
# Saved hsa00785: 23 nodes, 23 edges
# Removed 99 isolated nodes from hsa00790
# Saved hsa00790: 34 nodes, 65 edges
# Removed 57 isolated nodes from hsa00670
# Saved hsa00670: 47 nodes, 188 edges
# Removed 28 isolated nodes from hsa00830
# Saved hsa00830: 37 nodes, 166 edges
# Removed 269 isolated nodes from hsa00860
# Saved hsa00860: 21 nodes, 27 edges
# Removed 131 isolated nodes from hsa00130
# Saved hsa00130: 19 nodes, 16 edges
# Removed 89 isolated nodes from hsa00900
# Saved hsa00900: 26 nodes, 57 edges
# Removed 43 isolated nodes from hsa00232
# Saved hsa00232: 7 nodes, 10 edges
# Removed 162 isolated nodes from hsa00524
# Saved hsa00524: 3 nodes, 2 edges
# Removed 129 isolated nodes from hsa00980
# Saved hsa00980: 79 nodes, 144 edges
# Removed 98 isolated nodes from hsa00982
# Saved hsa00982: 53 nodes, 59 edges
# Removed 54 isolated nodes from hsa00983
# Saved hsa00983: 41 nodes, 66 edges
# Removed 64 isolated nodes from hsa03020
# Skipping hsa03020 (empty after cleaning)
# Removed 38 isolated nodes from hsa03022
# Skipping hsa03022 (empty after cleaning)
# Removed 91 isolated nodes from hsa03040
# Skipping hsa03040 (empty after cleaning)
# Removed 202 isolated nodes from hsa03010
# Skipping hsa03010 (empty after cleaning)
# Removed 83 isolated nodes from hsa00970
# Saved hsa00970: 35 nodes, 26 edges
# Removed 79 isolated nodes from hsa03013
# Skipping hsa03013 (empty after cleaning)
# Removed 45 isolated nodes from hsa03015
# Saved hsa03015: 25 nodes, 21 edges
# Removed 67 isolated nodes from hsa03008
# Skipping hsa03008 (empty after cleaning)
# Removed 49 isolated nodes from hsa03060
# Skipping hsa03060 (empty after cleaning)
# Removed 92 isolated nodes from hsa04141
# Saved hsa04141: 30 nodes, 29 edges
# Removed 30 isolated nodes from hsa04130
# Saved hsa04130: 12 nodes, 6 edges
# Removed 115 isolated nodes from hsa04120
# Skipping hsa04120 (empty after cleaning)
# Removed 52 isolated nodes from hsa04122
# Saved hsa04122: 9 nodes, 6 edges
# Removed 56 isolated nodes from hsa03050
# Skipping hsa03050 (empty after cleaning)
# Removed 74 isolated nodes from hsa03018
# Saved hsa03018: 5 nodes, 4 edges
# Removed 65 isolated nodes from hsa03030
# Skipping hsa03030 (empty after cleaning)
# Removed 65 isolated nodes from hsa03410
# Skipping hsa03410 (empty after cleaning)
# Removed 56 isolated nodes from hsa03420
# Skipping hsa03420 (empty after cleaning)
# Removed 32 isolated nodes from hsa03430
# Skipping hsa03430 (empty after cleaning)
# Removed 51 isolated nodes from hsa03440
# Saved hsa03440: 18 nodes, 20 edges
# Removed 21 isolated nodes from hsa03450
# Skipping hsa03450 (empty after cleaning)
# Removed 34 isolated nodes from hsa03460
# Saved hsa03460: 24 nodes, 22 edges
# Removed 102 isolated nodes from hsa03082
# Skipping hsa03082 (empty after cleaning)
# Removed 64 isolated nodes from hsa03083
# Skipping hsa03083 (empty after cleaning)
# Removed 68 isolated nodes from hsa03250
# Saved hsa03250: 17 nodes, 12 edges
# Removed 26 isolated nodes from hsa03260
# Skipping hsa03260 (empty after cleaning)
# Removed 14 isolated nodes from hsa03271
# Skipping hsa03271 (empty after cleaning)
# Removed 27 isolated nodes from hsa03264
# Skipping hsa03264 (empty after cleaning)
# Removed 39 isolated nodes from hsa03265
# Skipping hsa03265 (empty after cleaning)
# Removed 18 isolated nodes from hsa03273
# Skipping hsa03273 (empty after cleaning)
# Removed 52 isolated nodes from hsa03272
# Skipping hsa03272 (empty after cleaning)
# Removed 34 isolated nodes from hsa03266
# Skipping hsa03266 (empty after cleaning)
# Removed 20 isolated nodes from hsa03267
# Skipping hsa03267 (empty after cleaning)
# Removed 632 isolated nodes from hsa02010
# Skipping hsa02010 (empty after cleaning)
# Removed 11 isolated nodes from hsa04010
# Saved hsa04010: 123 nodes, 169 edges
# Removed 24 isolated nodes from hsa04012
# Saved hsa04012: 56 nodes, 85 edges
# Removed 14 isolated nodes from hsa04014
# Saved hsa04014: 94 nodes, 112 edges
# Removed 24 isolated nodes from hsa04015
# Saved hsa04015: 81 nodes, 90 edges
# Removed 16 isolated nodes from hsa04310
# Saved hsa04310: 85 nodes, 102 edges
# Removed 15 isolated nodes from hsa04330
# Saved hsa04330: 24 nodes, 23 edges
# Removed 9 isolated nodes from hsa04340
# Saved hsa04340: 58 nodes, 45 edges
# Removed 20 isolated nodes from hsa04350
# Saved hsa04350: 85 nodes, 75 edges
# Removed 34 isolated nodes from hsa04390
# Saved hsa04390: 76 nodes, 61 edges
# Removed 18 isolated nodes from hsa04392
# Saved hsa04392: 37 nodes, 26 edges
# Removed 12 isolated nodes from hsa04370
# Saved hsa04370: 28 nodes, 32 edges
# Removed 13 isolated nodes from hsa04371
# Saved hsa04371: 72 nodes, 76 edges
# Removed 43 isolated nodes from hsa04630
# Saved hsa04630: 72 nodes, 231 edges
# Removed 70 isolated nodes from hsa04064
# Saved hsa04064: 107 nodes, 96 edges
# Removed 52 isolated nodes from hsa04668
# Saved hsa04668: 60 nodes, 56 edges
# Removed 23 isolated nodes from hsa04066
# Saved hsa04066: 69 nodes, 67 edges
# Removed 23 isolated nodes from hsa04068
# Saved hsa04068: 76 nodes, 79 edges
# Removed 26 isolated nodes from hsa04020
# Saved hsa04020: 61 nodes, 66 edges
# Removed 37 isolated nodes from hsa04070
# Saved hsa04070: 46 nodes, 142 edges
# Removed 22 isolated nodes from hsa04072
# Saved hsa04072: 61 nodes, 71 edges
# Removed 25 isolated nodes from hsa04071
# Saved hsa04071: 63 nodes, 72 edges
# Removed 33 isolated nodes from hsa04024
# Saved hsa04024: 107 nodes, 118 edges
# Removed 18 isolated nodes from hsa04022
# Saved hsa04022: 72 nodes, 73 edges
# Removed 36 isolated nodes from hsa04151
# Saved hsa04151: 84 nodes, 85 edges
# Removed 40 isolated nodes from hsa04152
# Saved hsa04152: 68 nodes, 63 edges
# Removed 13 isolated nodes from hsa04150
# Saved hsa04150: 80 nodes, 84 edges
# Removed 3 isolated nodes from hsa04080
# Saved hsa04080: 194 nodes, 105 edges
# Removed 33 isolated nodes from hsa04082
# Saved hsa04082: 158 nodes, 132 edges
# Removed 25 isolated nodes from hsa04081
# Saved hsa04081: 293 nodes, 258 edges
# Removed 150 isolated nodes from hsa04060
# Saved hsa04060: 290 nodes, 288 edges
# Removed 201 isolated nodes from hsa04061
# Saved hsa04061: 62 nodes, 37 edges
# Removed 49 isolated nodes from hsa04512
# Saved hsa04512: 99 nodes, 71 edges
# Removed 64 isolated nodes from hsa04514
# Saved hsa04514: 219 nodes, 141 edges
# Removed 49 isolated nodes from hsa04517
# Saved hsa04517: 299 nodes, 327 edges
# Removed 107 isolated nodes from hsa04144
# Saved hsa04144: 36 nodes, 24 edges
# Removed 80 isolated nodes from hsa04145
# Saved hsa04145: 6 nodes, 3 edges
# Removed 87 isolated nodes from hsa04142
# Skipping hsa04142 (empty after cleaning)
# Removed 67 isolated nodes from hsa04146
# Saved hsa04146: 7 nodes, 5 edges
# Removed 27 isolated nodes from hsa04140
# Saved hsa04140: 111 nodes, 132 edges
# Removed 16 isolated nodes from hsa04136
# Saved hsa04136: 23 nodes, 19 edges
# Removed 18 isolated nodes from hsa04137
# Saved hsa04137: 70 nodes, 71 edges
# Removed 38 isolated nodes from hsa04148
# Saved hsa04148: 95 nodes, 102 edges
# Removed 61 isolated nodes from hsa04110
# Saved hsa04110: 73 nodes, 79 edges
# Removed 29 isolated nodes from hsa04114
# Saved hsa04114: 62 nodes, 62 edges
# Removed 24 isolated nodes from hsa04210
# Saved hsa04210: 100 nodes, 135 edges
# Removed 27 isolated nodes from hsa04215
# Saved hsa04215: 24 nodes, 20 edges
# Removed 44 isolated nodes from hsa04216
# Saved hsa04216: 33 nodes, 22 edges
# Removed 27 isolated nodes from hsa04217
# Saved hsa04217: 71 nodes, 67 edges
# Removed 12 isolated nodes from hsa04115
# Saved hsa04115: 62 nodes, 69 edges
# Removed 27 isolated nodes from hsa04218
# Saved hsa04218: 97 nodes, 99 edges
# Removed 11 isolated nodes from hsa04510
# Saved hsa04510: 63 nodes, 103 edges
# Removed 18 isolated nodes from hsa04520
# Saved hsa04520: 81 nodes, 95 edges
# Removed 8 isolated nodes from hsa04530
# Saved hsa04530: 131 nodes, 138 edges
# Removed 12 isolated nodes from hsa04540
# Saved hsa04540: 48 nodes, 56 edges
# Removed 44 isolated nodes from hsa04550
# Saved hsa04550: 64 nodes, 58 edges
# Removed 115 isolated nodes from hsa04814
# Skipping hsa04814 (empty after cleaning)
# Removed 111 isolated nodes from hsa04820
# Skipping hsa04820 (empty after cleaning)
# Removed 16 isolated nodes from hsa04810
# Saved hsa04810: 77 nodes, 89 edges
# Removed 138 isolated nodes from hsa04640
# Skipping hsa04640 (empty after cleaning)
# Removed 33 isolated nodes from hsa04610
# Saved hsa04610: 98 nodes, 98 edges
# Removed 18 isolated nodes from hsa04611
# Saved hsa04611: 78 nodes, 85 edges
# Removed 49 isolated nodes from hsa04613
# Saved hsa04613: 71 nodes, 79 edges
# Removed 23 isolated nodes from hsa04620
# Saved hsa04620: 79 nodes, 103 edges
# Removed 32 isolated nodes from hsa04621
# Saved hsa04621: 158 nodes, 163 edges
# Removed 15 isolated nodes from hsa04622
# Saved hsa04622: 53 nodes, 62 edges
# Removed 18 isolated nodes from hsa04623
# Saved hsa04623: 46 nodes, 53 edges
# Removed 12 isolated nodes from hsa04625
# Saved hsa04625: 183 nodes, 156 edges
# Removed 28 isolated nodes from hsa04650
# Saved hsa04650: 78 nodes, 107 edges
# Removed 19 isolated nodes from hsa04612
# Saved hsa04612: 27 nodes, 22 edges
# Removed 19 isolated nodes from hsa04660
# Saved hsa04660: 65 nodes, 96 edges
# Removed 21 isolated nodes from hsa04658
# Saved hsa04658: 61 nodes, 113 edges
# Removed 39 isolated nodes from hsa04659
# Saved hsa04659: 81 nodes, 82 edges
# Removed 30 isolated nodes from hsa04657
# Saved hsa04657: 77 nodes, 134 edges
# Removed 15 isolated nodes from hsa04662
# Saved hsa04662: 46 nodes, 51 edges
# Removed 24 isolated nodes from hsa04664
# Saved hsa04664: 35 nodes, 41 edges
# Removed 9 isolated nodes from hsa04666
# Saved hsa04666: 54 nodes, 70 edges
# Removed 34 isolated nodes from hsa04670
# Saved hsa04670: 61 nodes, 62 edges
# Removed 33 isolated nodes from hsa04672
# Saved hsa04672: 29 nodes, 19 edges
# Removed 17 isolated nodes from hsa04062
# Saved hsa04062: 56 nodes, 72 edges
# Removed 23 isolated nodes from hsa04911
# Saved hsa04911: 38 nodes, 38 edges
# Removed 10 isolated nodes from hsa04910
# Saved hsa04910: 65 nodes, 76 edges
# Removed 47 isolated nodes from hsa04922
# Saved hsa04922: 46 nodes, 49 edges
# Removed 24 isolated nodes from hsa04923
# Saved hsa04923: 47 nodes, 40 edges
# Removed 5 isolated nodes from hsa04920
# Saved hsa04920: 44 nodes, 50 edges
# Removed 10 isolated nodes from hsa03320
# Saved hsa03320: 55 nodes, 60 edges
# Removed 21 isolated nodes from hsa04929
# Saved hsa04929: 34 nodes, 37 edges
# Removed 17 isolated nodes from hsa04912
# Saved hsa04912: 37 nodes, 39 edges
# Removed 47 isolated nodes from hsa04913
# Saved hsa04913: 30 nodes, 25 edges
# Removed 16 isolated nodes from hsa04915
# Saved hsa04915: 70 nodes, 68 edges
# Removed 9 isolated nodes from hsa04914
# Saved hsa04914: 35 nodes, 28 edges
# Removed 23 isolated nodes from hsa04917
# Saved hsa04917: 52 nodes, 55 edges
# Removed 17 isolated nodes from hsa04921
# Saved hsa04921: 65 nodes, 73 edges
# Removed 11 isolated nodes from hsa04926
# Saved hsa04926: 89 nodes, 102 edges
# Removed 12 isolated nodes from hsa04935
# Saved hsa04935: 59 nodes, 76 edges
# Removed 67 isolated nodes from hsa04918
# Saved hsa04918: 36 nodes, 36 edges
# Removed 48 isolated nodes from hsa04919
# Saved hsa04919: 73 nodes, 71 edges
# Removed 24 isolated nodes from hsa04928
# Saved hsa04928: 78 nodes, 77 edges
# Removed 13 isolated nodes from hsa04916
# Saved hsa04916: 37 nodes, 31 edges
# Removed 24 isolated nodes from hsa04924
# Saved hsa04924: 38 nodes, 35 edges
# Removed 12 isolated nodes from hsa04614
# Saved hsa04614: 33 nodes, 48 edges
# Removed 48 isolated nodes from hsa04925
# Saved hsa04925: 30 nodes, 29 edges
# Removed 37 isolated nodes from hsa04927
# Saved hsa04927: 28 nodes, 42 edges
# Removed 26 isolated nodes from hsa04260
# Saved hsa04260: 20 nodes, 19 edges
# Removed 19 isolated nodes from hsa04261
# Saved hsa04261: 60 nodes, 70 edges
# Removed 12 isolated nodes from hsa04270
# Saved hsa04270: 63 nodes, 62 edges
# Removed 44 isolated nodes from hsa04970
# Saved hsa04970: 31 nodes, 29 edges
# Removed 29 isolated nodes from hsa04971
# Saved hsa04971: 28 nodes, 25 edges
# Removed 71 isolated nodes from hsa04972
# Saved hsa04972: 27 nodes, 24 edges
# Removed 130 isolated nodes from hsa04976
# Saved hsa04976: 21 nodes, 18 edges
# Removed 59 isolated nodes from hsa04973
# Saved hsa04973: 11 nodes, 9 edges
# Removed 79 isolated nodes from hsa04974
# Saved hsa04974: 2 nodes, 1 edges
# Removed 64 isolated nodes from hsa04975
# Saved hsa04975: 8 nodes, 5 edges
# Removed 86 isolated nodes from hsa04979
# Saved hsa04979: 42 nodes, 27 edges
# Removed 100 isolated nodes from hsa04977
# Saved hsa04977: 18 nodes, 9 edges
# Removed 112 isolated nodes from hsa04981
# Skipping hsa04981 (empty after cleaning)
# Removed 19 isolated nodes from hsa04980
# Saved hsa04980: 27 nodes, 19 edges
# Removed 69 isolated nodes from hsa04978
# Saved hsa04978: 22 nodes, 14 edges
# Removed 20 isolated nodes from hsa04962
# Saved hsa04962: 11 nodes, 10 edges
# Removed 14 isolated nodes from hsa04960
# Saved hsa04960: 19 nodes, 20 edges
# Removed 20 isolated nodes from hsa04961
# Saved hsa04961: 40 nodes, 32 edges
# Removed 48 isolated nodes from hsa04964
# Saved hsa04964: 4 nodes, 2 edges
# Removed 14 isolated nodes from hsa04966
# Saved hsa04966: 10 nodes, 6 edges
# Removed 33 isolated nodes from hsa04724
# Saved hsa04724: 46 nodes, 53 edges
# Removed 39 isolated nodes from hsa04727
# Saved hsa04727: 23 nodes, 19 edges
# Removed 28 isolated nodes from hsa04725
# Saved hsa04725: 39 nodes, 45 edges
# Removed 37 isolated nodes from hsa04728
# Saved hsa04728: 42 nodes, 54 edges
# Removed 40 isolated nodes from hsa04726
# Saved hsa04726: 44 nodes, 40 edges
# Removed 10 isolated nodes from hsa04720
# Saved hsa04720: 26 nodes, 38 edges
# Removed 14 isolated nodes from hsa04730
# Saved hsa04730: 36 nodes, 41 edges
# Removed 56 isolated nodes from hsa04723
# Saved hsa04723: 36 nodes, 31 edges
# Removed 29 isolated nodes from hsa04721
# Saved hsa04721: 13 nodes, 8 edges
# Removed 12 isolated nodes from hsa04722
# Saved hsa04722: 77 nodes, 116 edges
# Removed 21 isolated nodes from hsa04744
# Saved hsa04744: 29 nodes, 20 edges
# Removed 16 isolated nodes from hsa04740
# Saved hsa04740: 31 nodes, 28 edges
# Removed 28 isolated nodes from hsa04742
# Saved hsa04742: 46 nodes, 38 edges
# Removed 13 isolated nodes from hsa04750
# Saved hsa04750: 81 nodes, 80 edges
# Removed 24 isolated nodes from hsa04360
# Saved hsa04360: 137 nodes, 139 edges
# Removed 17 isolated nodes from hsa04380
# Saved hsa04380: 69 nodes, 83 edges
# Removed 103 isolated nodes from hsa04382
# Saved hsa04382: 2 nodes, 1 edges
# Removed 16 isolated nodes from hsa04211
# Saved hsa04211: 48 nodes, 54 edges
# Removed 23 isolated nodes from hsa04213
# Saved hsa04213: 49 nodes, 52 edges
# Removed 23 isolated nodes from hsa04710
# Saved hsa04710: 25 nodes, 26 edges
# Removed 15 isolated nodes from hsa04713
# Saved hsa04713: 48 nodes, 70 edges
# Removed 40 isolated nodes from hsa04714
# Saved hsa04714: 52 nodes, 64 edges
# Removed 88 isolated nodes from hsa05200
# Saved hsa05200: 259 nodes, 282 edges
# Removed 199 isolated nodes from hsa05202
# Saved hsa05202: 16 nodes, 9 edges
# Removed 118 isolated nodes from hsa05206
# Saved hsa05206: 342 nodes, 230 edges
# Removed 37 isolated nodes from hsa05205
# Saved hsa05205: 183 nodes, 187 edges
# Removed 125 isolated nodes from hsa05204
# Saved hsa05204: 27 nodes, 31 edges
# Removed 45 isolated nodes from hsa05207
# Saved hsa05207: 152 nodes, 146 edges
# Removed 161 isolated nodes from hsa05208
# Saved hsa05208: 75 nodes, 79 edges
# Removed 234 isolated nodes from hsa05203
# Saved hsa05203: 6 nodes, 3 edges
# Removed 91 isolated nodes from hsa05230
# Saved hsa05230: 40 nodes, 38 edges
# Removed 23 isolated nodes from hsa05231
# Saved hsa05231: 37 nodes, 41 edges
# Removed 22 isolated nodes from hsa05235
# Saved hsa05235: 71 nodes, 80 edges
# Removed 26 isolated nodes from hsa05210
# Saved hsa05210: 60 nodes, 56 edges
# Removed 10 isolated nodes from hsa05212
# Saved hsa05212: 58 nodes, 52 edges
# Removed 43 isolated nodes from hsa05225
# Saved hsa05225: 88 nodes, 76 edges
# Removed 26 isolated nodes from hsa05226
# Saved hsa05226: 87 nodes, 73 edges
# Removed 16 isolated nodes from hsa05214
# Saved hsa05214: 70 nodes, 77 edges
# Removed 7 isolated nodes from hsa05216
# Saved hsa05216: 25 nodes, 20 edges
# Removed 10 isolated nodes from hsa05221
# Saved hsa05221: 47 nodes, 53 edges
# Removed 18 isolated nodes from hsa05220
# Saved hsa05220: 46 nodes, 42 edges
# Removed 9 isolated nodes from hsa05217
# Saved hsa05217: 23 nodes, 20 edges
# Removed 11 isolated nodes from hsa05218
# Saved hsa05218: 30 nodes, 27 edges
# Removed 29 isolated nodes from hsa05211
# Saved hsa05211: 39 nodes, 35 edges
# Removed 20 isolated nodes from hsa05219
# Saved hsa05219: 20 nodes, 16 edges
# Removed 39 isolated nodes from hsa05215
# Saved hsa05215: 44 nodes, 43 edges
# Removed 18 isolated nodes from hsa05213
# Saved hsa05213: 38 nodes, 34 edges
# Removed 20 isolated nodes from hsa05224
# Saved hsa05224: 110 nodes, 104 edges
# Removed 19 isolated nodes from hsa05222
# Saved hsa05222: 41 nodes, 36 edges
# Removed 15 isolated nodes from hsa05223
# Saved hsa05223: 54 nodes, 59 edges
# Removed 74 isolated nodes from hsa05166
# Saved hsa05166: 97 nodes, 89 edges
# Removed 75 isolated nodes from hsa05170
# Saved hsa05170: 107 nodes, 102 edges
# Removed 70 isolated nodes from hsa05161
# Saved hsa05161: 110 nodes, 92 edges
# Removed 52 isolated nodes from hsa05160
# Saved hsa05160: 82 nodes, 80 edges
# Removed 99 isolated nodes from hsa05171
# Saved hsa05171: 110 nodes, 91 edges
# Removed 87 isolated nodes from hsa05164
# Saved hsa05164: 81 nodes, 86 edges
# Removed 65 isolated nodes from hsa05162
# Saved hsa05162: 77 nodes, 71 edges
# Removed 75 isolated nodes from hsa05168
# Saved hsa05168: 106 nodes, 98 edges
# Removed 68 isolated nodes from hsa05163
# Saved hsa05163: 140 nodes, 131 edges
#
# Saved 266 cleaned KEGG pathway graphs into 'train_data.dat'

# %%
# import Bio
# Bio.__file__  # shows the path to BioPython's install location
